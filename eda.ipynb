# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import matplotlib as mpl

# 1) Disable LaTeX parsing to avoid '$' or special-character issues
mpl.rcParams['text.usetex'] = False
mpl.rcParams['axes.unicode_minus'] = False

# %matplotlib inline
sns.set_style("whitegrid")

# Load your data
df = pd.read_csv('clean_tabular_data.csv')

# Replace placeholder '--' with NaN if necessary
df.replace('--', np.nan, inplace=True)

print("Data shape:", df.shape)
df.info()
display(df.head())

# Missing values
print("\nMissing values per column:")
print(df.isnull().sum())

msno.bar(df)
plt.title("Missing Values - Bar Plot")
plt.show()

# EXAMPLE: If msno.heatmap fails, wrap in try-except
try:
    msno.heatmap(df)
    plt.title("Missing Values - Heatmap")
    plt.show()
except ValueError as e:
    print(f"Heatmap error: {e}")

# Basic stats
display(df.describe(include='all'))

# Separate numeric vs. categorical
numeric_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(include=['object','category']).columns

# Numeric distribution
for col in numeric_cols:
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True, color='blue')
    plt.title(f"{col} Distribution")

    plt.subplot(1,2,2)
    sns.boxplot(x=df[col], color='orange')
    plt.title(f"{col} Boxplot")

    plt.tight_layout()
    plt.show()

# Categorical distribution (skip huge columns)
for col in categorical_cols:
    unique_vals = df[col].nunique()
    if unique_vals > 20:
        print(f"Skipping {col} (too many unique values: {unique_vals})")
        continue

    plt.figure(figsize=(8,4))
    sns.countplot(x=df[col], palette='viridis')
    plt.title(f"Count Plot - {col}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# Check skew
skews = df[numeric_cols].skew().sort_values(ascending=False)
print("\nSkewness:\n", skews)

# Correlation
corr = df[numeric_cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Pairplot (can be large)
sns.pairplot(df[numeric_cols], diag_kind='kde', corner=True)
plt.suptitle("Pairwise Plots", y=1.02)
plt.show()
# Out:
# Data shape: (830, 19)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    830 non-null    object
#  1   Category              830 non-null    object
#  2   Title                 830 non-null    object
#  3   Description           830 non-null    object
#  4   Amenities             830 non-null    object
#  5   Location              830 non-null    object
#  6   guests                830 non-null    int64
#  7   beds                  830 non-null    float64
#  8   bathrooms             830 non-null    float64
#  9   Price_Night           830 non-null    int64
#  10  Cleanliness_rating    830 non-null    float64
#  11  Accuracy_rating       830 non-null    float64
#  12  Communication_rating  830 non-null    float64
#  13  Location_rating       830 non-null    float64
#  14  Check-in_rating       830 non-null    float64
#  15  Value_rating          830 non-null    float64
#  16  amenities_count       830 non-null    float64
#  17  url                   830 non-null    object
#  18  bedrooms              830 non-null    int64
# dtypes: float64(9), int64(3), object(7)
# memory usage: 123.3+ KB
#                                      ID    Category  \
# 0  f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Treehouses
# 1  1b4736a7-e73e-45bc-a9b5-d3e7fcf652fd  Treehouses
# 2  d577bc30-2222-4bef-a35e-a9825642aec4  Treehouses
# 3  ca9cbfd4-7798-4e8d-8c17-d5a64fba0abc  Treehouses
# 4  cfe479b9-c8f8-44af-9bc6-46ede9f14bb5  Treehouses
#
#                                               Title  \
# 0                 Red Kite Tree Tent - Ynys Affalon
# 1    Az Alom Cabin - Treehouse Tree to Nature Cabin
# 2                       Cabane Entre Les Pins\n🌲🏕️🌲
# 3  Tree Top Cabin with log burner & private hot tub
# 4                       Treehouse near Paris Disney
#
#                                          Description  \
# 0  "Escape to one of these two fabulous Tree Tent...
# 1  "Come and spend a romantic stay with a couple ...
# 2  'Rustic cabin between the pines, 3 meters high...
# 3  'The Tree top cabin is situated in our peacefu...
# 4  'Charming cabin nestled in the leaves, real un...
#
#                                            Amenities  \
# 0  'Bathroom', 'Shampoo', 'Bedroom and laundry', ...
# 1  'Bedroom and laundry', 'Essentials', 'Towels, ...
# 2  'Scenic views', 'Garden view', 'River view', '...
# 3  'Bathroom', 'Hot water', 'Bedroom and laundry'...
# 4  'Bathroom', 'Hair dryer', 'Shampoo', 'Hot wate...
#
#                                       Location  guests  beds  bathrooms  \
# 0             Llandrindod Wells United Kingdom       2   1.0        1.0
# 1                  Guyonvelle Grand Est France       3   3.0        0.0
# 2                     Duclair Normandie France       4   2.0        1.5
# 3                Barmouth Wales United Kingdom       2   1.0        1.0
# 4  Le Plessis-Feu-Aussoux Île-de-France France       4   3.0        1.0
#
#    Price_Night  Cleanliness_rating  Accuracy_rating  Communication_rating  \
# 0          105                 4.6              4.7                   4.3
# 1           92                 4.3              4.7                   4.6
# 2           52                 4.2              4.6                   4.8
# 3          132                 4.8              4.9                   4.9
# 4          143                 5.0              4.9                   5.0
#
#    Location_rating  Check-in_rating  Value_rating  amenities_count  \
# 0              5.0              4.3           4.3             13.0
# 1              4.9              4.7           4.5              8.0
# 2              4.8              4.8           4.7             51.0
# 3              4.9              5.0           4.6             23.0
# 4              4.7              5.0           4.7             32.0
#
#                                                  url  bedrooms
# 0  https://www.airbnb.co.uk/rooms/26620994?adults...         1
# 1  https://www.airbnb.co.uk/rooms/27055498?adults...         1
# 2  https://www.airbnb.co.uk/rooms/51427108?adults...         1
# 3  https://www.airbnb.co.uk/rooms/49543851?adults...         1
# 4  https://www.airbnb.co.uk/rooms/935398?adults=1...         2
# Missing values per column:
# ID                      0
# Category                0
# Title                   0
# Description             0
# Amenities               0
# Location                0
# guests                  0
# beds                    0
# bathrooms               0
# Price_Night             0
# Cleanliness_rating      0
# Accuracy_rating         0
# Communication_rating    0
# Location_rating         0
# Check-in_rating         0
# Value_rating            0
# amenities_count         0
# url                     0
# bedrooms                0
# dtype: int64
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
#                                           ID Category           Title  \
# count                                    830      830             830
# unique                                   830        5             820
# top     f9dcbd09-32ac-41d9-a0b1-fdb2793378cf  Chalets  The Pool House
# freq                                       1      192               5
# mean                                     NaN      NaN             NaN
# std                                      NaN      NaN             NaN
# min                                      NaN      NaN             NaN
# 25%                                      NaN      NaN             NaN
# 50%                                      NaN      NaN             NaN
# 75%                                      NaN      NaN             NaN
# max                                      NaN      NaN             NaN
#
#                                               Description  \
# count                                                 830
# unique                                                827
# top     'The Barkhouse is the only fully tree supporte...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 Amenities  \
# count                                                 830
# unique                                                822
# top     'Bathroom', 'Hair dryer', 'Bedroom and laundry...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   Location      guests        beds  \
# count                                  830  830.000000  830.000000
# unique                                 653         NaN         NaN
# top     West Sussex England United Kingdom         NaN         NaN
# freq                                    19         NaN         NaN
# mean                                   NaN    3.908434    2.425301
# std                                    NaN    2.378290    1.844651
# min                                    NaN    1.000000    1.000000
# 25%                                    NaN    2.000000    1.000000
# 50%                                    NaN    4.000000    2.000000
# 75%                                    NaN    4.750000    3.000000
# max                                    NaN   16.000000   17.000000
#
#          bathrooms  Price_Night  Cleanliness_rating  Accuracy_rating  \
# count   830.000000   830.000000          830.000000       830.000000
# unique         NaN          NaN                 NaN              NaN
# top            NaN          NaN                 NaN              NaN
# freq           NaN          NaN                 NaN              NaN
# mean      1.376506   153.934940            5.088916         4.905904
# std       0.827813   129.179626            6.776068         0.130051
# min       0.000000     3.000000            3.800000         4.000000
# 25%       1.000000    83.000000            4.800000         4.900000
# 50%       1.000000   120.000000            4.900000         4.900000
# 75%       1.500000   176.000000            5.000000         5.000000
# max      10.000000  1132.000000          200.000000         5.000000
#
#         Communication_rating  Location_rating  Check-in_rating  Value_rating  \
# count             830.000000       830.000000       830.000000    830.000000
# unique                   NaN              NaN              NaN           NaN
# top                      NaN              NaN              NaN           NaN
# freq                     NaN              NaN              NaN           NaN
# mean                4.933494         4.905060         4.944458      4.769277
# std                 0.121753         0.120707         0.104018      0.174995
# min                 3.900000         4.000000         3.900000      3.700000
# 25%                 4.900000         4.900000         4.900000      4.700000
# 50%                 5.000000         4.900000         5.000000      4.800000
# 75%                 5.000000         5.000000         5.000000      4.900000
# max                 5.000000         5.000000         5.000000      5.000000
#
#         amenities_count                                                url  \
# count        830.000000                                                830
# unique              NaN                                                830
# top                 NaN  https://www.airbnb.co.uk/rooms/26620994?adults...
# freq                NaN                                                  1
# mean          35.451446                                                NaN
# std           14.256733                                                NaN
# min            3.000000                                                NaN
# 25%           25.000000                                                NaN
# 50%           35.000000                                                NaN
# 75%           44.000000                                                NaN
# max           84.000000                                                NaN
#
#           bedrooms
# count   830.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean      1.646988
# std       1.060059
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max      10.000000
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Skipping ID (too many unique values: 830)
# Skipping Title (too many unique values: 820)
# Skipping Description (too many unique values: 827)
# Skipping Amenities (too many unique values: 822)
# Skipping Location (too many unique values: 653)
# Skipping url (too many unique values: 830)
#
# Skewness:
#  Cleanliness_rating      28.778434
# bathrooms                3.406029
# Price_Night              3.137970
# bedrooms                 2.415986
# beds                     2.353697
# guests                   1.903880
# amenities_count          0.373150
# Value_rating            -1.500761
# Accuracy_rating         -2.385572
# Location_rating         -2.551751
# Communication_rating    -3.387381
# Check-in_rating         -3.590940
# dtype: float64
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/airbnb/lib/python3.13/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
